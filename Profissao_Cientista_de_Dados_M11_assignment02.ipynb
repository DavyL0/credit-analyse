# %% [markdown]
# <a href="https://colab.research.google.com/github/DavyL0/credit-analyse/blob/main/Profissao_Cientista_de_Dados_M11_assignment02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Árvores de regressão - exercícios 02
#
# Este exercício será uma continuação do anterior, mesma base, mesmas variáveis - vamos tentar buscar a 'melhor árvore'.

# %% [markdown]
# *Atenção - Utilizar a base de dados em anexo que é a mesma base que utilizamos na atividade anterior! A base Boston, assim como para a primeira atividade foi descontinuada e não deve ser utilizada*

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings

from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1. Execute os passos do exercício anterior, até que você tenha uma árvore de regressão predizendo o valor do imóvel na base de treinamento.

# %%
house = pd.read_csv('housing.csv')
house.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
scaler = StandardScaler()
house[['total_rooms', 'total_bedrooms']] = scaler.fit_transform(house[['total_rooms', 'total_bedrooms']])
house['median_income'] = house['median_income'].astype(int)
house.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0    -0.804819       -0.970325
# 1    -122.22     37.86                21.0     2.045890        1.348276
# 2    -122.24     37.85                52.0    -0.535746       -0.825561
# 3    -122.25     37.85                52.0    -0.624215       -0.718768
# 4    -122.25     37.85                52.0    -0.462404       -0.611974
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0              8            452600.0        NEAR BAY
# 1      2401.0      1138.0              8            358500.0        NEAR BAY
# 2       496.0       177.0              7            352100.0        NEAR BAY
# 3       558.0       219.0              5            341300.0        NEAR BAY
# 4       565.0       259.0              3            342200.0        NEAR BAY

# %%
X = house.drop(columns = ['longitude', 'median_house_value', 'latitude','population','households']).copy()

X = pd.get_dummies(X, drop_first = True)
print(X.info())

y =  house.loc[:,'median_house_value']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   housing_median_age          20640 non-null  float64
#  1   total_rooms                 20640 non-null  float64
#  2   total_bedrooms              20433 non-null  float64
#  3   median_income               20640 non-null  int64
#  4   ocean_proximity_INLAND      20640 non-null  bool
#  5   ocean_proximity_ISLAND      20640 non-null  bool
#  6   ocean_proximity_NEAR BAY    20640 non-null  bool
#  7   ocean_proximity_NEAR OCEAN  20640 non-null  bool
# dtypes: bool(4), float64(3), int64(1)
# memory usage: 725.8 KB
# None

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2360873)

# %%
# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=8)

regr_1.fit(X_train, y_train)
regr_2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=8)

# %%
representacao_textual = tree.export_text(regr_1)
print(representacao_textual)
# Out:
# |--- feature_3 <= 4.50
# |   |--- feature_4 <= 0.50
# |   |   |--- value: [207547.50]
# |   |--- feature_4 >  0.50
# |   |   |--- value: [112101.29]
# |--- feature_3 >  4.50
# |   |--- feature_3 <= 6.50
# |   |   |--- value: [292459.32]
# |   |--- feature_3 >  6.50
# |   |   |--- value: [428306.99]

# %%
# mse1 = mean_squared_error(y_test, regr_1.predict(X_test))
mse1 = regr_1.score(X_train, y_train)
mse2 = regr_2.score(X_train, y_train)

template = "O MSE da árvore com profundidade={0} é: {1:.2f}"

print(template.format(regr_1.get_depth(),mse1).replace(".",","))
print(template.format(regr_2.get_depth(),mse2).replace(".",","))
# Out:
# O MSE da árvore com profundidade=2 é: 0,49
# O MSE da árvore com profundidade=8 é: 0,68

# %% [markdown]
# ### 2.  Calcule o caminho indicado pelos CCP-alfas dessa árvore.

# %%
regr_1 = DecisionTreeRegressor(max_depth=3, min_samples_leaf=10)

regr_1.fit(X_train, y_train)

mse1 = regr_1.score(X_test, y_test)
mse1
# Out:
# 0.5668605971728278

# %%
mses = []
ind_i = []
ind_j = []

for i in range(2, 9):
    for j in range(2, 10):
        regr_1 = DecisionTreeRegressor(max_depth=i, min_samples_leaf=j)
        regr_1.fit(X_train, y_train)
        mse1 = regr_1.score(X_test, y_test)
        mses.append(mse1)
        ind_i.append(i)
        ind_j.append(j)

df_mse = pd.DataFrame({'mses':mses, 'profundidade':ind_i, 'n_minimo':ind_j})
sns.heatmap(df_mse.pivot(index='profundidade', columns='n_minimo', values='mses'))
df_mse.pivot(index='profundidade', columns='n_minimo', values='mses')
# Out:
# n_minimo             2         3         4         5         6         7  \
# profundidade
# 2             0.492973  0.492973  0.492973  0.492973  0.492973  0.492973
# 3             0.566861  0.566861  0.566861  0.566861  0.566861  0.566861
# 4             0.601236  0.601236  0.601236  0.601236  0.601236  0.601236
# 5             0.615968  0.616578  0.616285  0.616101  0.616038  0.615732
# 6             0.627689  0.627741  0.627325  0.627387  0.627664  0.626584
# 7             0.633732  0.634015  0.634243  0.634324  0.634857  0.633373
# 8             0.636051  0.634520  0.636841  0.637822  0.637714  0.635879
#
# n_minimo             8         9
# profundidade
# 2             0.492973  0.492973
# 3             0.566861  0.566861
# 4             0.601236  0.601236
# 5             0.616046  0.616046
# 6             0.627394  0.627394
# 7             0.634538  0.634604
# 8             0.637414  0.638090

# %%
path = regr_2.cost_complexity_pruning_path(X_train, y_train)
path
# Out:
# {'ccp_alphas': array([0.00000000e+00, 6.05620155e+02, 3.75193798e+03, 5.04683463e+03,
#         6.15116279e+03, 9.89179587e+03, 2.01873385e+04, 2.10029070e+04,
#         2.18708010e+04, 3.73385013e+04, 4.02483850e+04, 6.05620155e+04,
#         8.46718346e+04, 1.10537791e+05, 1.16111628e+05, 1.80558247e+05,
#         2.25441430e+05, 2.69798557e+05, 3.07049419e+05, 3.09703785e+05,
#         3.73206772e+05, 3.84674557e+05, 4.09186531e+05, 4.30671835e+05,
#         4.32378956e+05, 4.57515097e+05, 4.65600775e+05, 4.95118435e+05,
#         4.98229093e+05, 5.13107050e+05, 5.25072434e+05, 5.87275101e+05,
#         5.99025001e+05, 6.33500775e+05, 7.26922997e+05, 7.28689683e+05,
#         7.33465530e+05, 8.18661406e+05, 8.19919044e+05, 8.39014426e+05,
#         8.69153601e+05, 8.71139810e+05, 9.19068498e+05, 9.47594659e+05,
#         9.63956649e+05, 9.64825854e+05, 9.83795592e+05, 1.03086537e+06,
#         1.09013081e+06, 1.11583478e+06, 1.11979167e+06, 1.13130732e+06,
#         1.16606210e+06, 1.22703083e+06, 1.41894647e+06, 1.43945513e+06,
#         1.44711169e+06, 1.45118957e+06, 1.47217881e+06, 1.47223381e+06,
#         1.49421749e+06, 1.57949700e+06, 1.70118702e+06, 1.70259682e+06,
#         1.71221399e+06, 1.75205669e+06, 1.80074529e+06, 1.80295894e+06,
#         1.84564858e+06, 1.86881688e+06, 1.90227063e+06, 1.91143753e+06,
#         1.92522959e+06, 1.92900465e+06, 1.94691494e+06, 1.99909469e+06,
#         2.01882156e+06, 2.02231523e+06, 2.05939955e+06, 2.06084247e+06,
plt.xlabel("Alpha efetivo")
plt.ylabel("Impureza total das folhas")
# Out:
# Text(0, 0.5, 'Impureza total das folhas')

# %% [markdown]
# ### 3. Paca cada valor de alpha obtido no item 2, treine uma árvore com o respectivo alfa, e guarde essa árvore em uma lista.

# %%
clfs = []

for ccp_alpha in ccp_alphas:
    clf = DecisionTreeRegressor(random_state=0, ccp_alpha=ccp_alpha)
    clf.fit(X_train, y_train)
    clfs.append(clf)

# %%
print(clfs)
# Out:
# [DecisionTreeRegressor(random_state=0), DecisionTreeRegressor(ccp_alpha=605.6201550382611, random_state=0), DecisionTreeRegressor(ccp_alpha=3751.937984495877, random_state=0), DecisionTreeRegressor(ccp_alpha=5046.834625322997, random_state=0), DecisionTreeRegressor(ccp_alpha=6151.162790697675, random_state=0), DecisionTreeRegressor(ccp_alpha=9891.795865633076, random_state=0), DecisionTreeRegressor(ccp_alpha=20187.33850129199, random_state=0), DecisionTreeRegressor(ccp_alpha=21002.906976744187, random_state=0), DecisionTreeRegressor(ccp_alpha=21870.80103359185, random_state=0), DecisionTreeRegressor(ccp_alpha=37338.50129198966, random_state=0), DecisionTreeRegressor(ccp_alpha=40248.3850129199, random_state=0), DecisionTreeRegressor(ccp_alpha=60562.01550387597, random_state=0), DecisionTreeRegressor(ccp_alpha=84671.834625323, random_state=0), DecisionTreeRegressor(ccp_alpha=110537.79069767441, random_state=0), DecisionTreeRegressor(ccp_alpha=116111.62790697675, random_state=0), DecisionTreeRegressor(ccp_alpha=180558.24720068742, random_state=0), DecisionTreeRegressor(ccp_alpha=225441.4300911501, random_state=0), DecisionTreeRegressor(ccp_alpha=269798.55727821175, random_state=0), DecisionTreeRegressor(ccp_alpha=307049.4186046512, random_state=0), DecisionTreeRegressor(ccp_alpha=309703.7847908768, random_state=0), DecisionTreeRegressor(ccp_alpha=373206.77217915945, random_state=0), DecisionTreeRegressor(ccp_alpha=384674.55703211244, random_state=0), DecisionTreeRegressor(ccp_alpha=409186.53100775095, random_state=0), DecisionTreeRegressor(ccp_alpha=430671.8346683946, random_state=0), DecisionTreeRegressor(ccp_alpha=432378.95634019095, random_state=0), DecisionTreeRegressor(ccp_alpha=457515.0969484551, random_state=0), DecisionTreeRegressor(ccp_alpha=465600.77519379894, random_state=0), DecisionTreeRegressor(ccp_alpha=495118.43493585475, random_state=0), DecisionTreeRegressor(ccp_alpha=498229.0933720041, random_state=0), DecisionTreeRegressor(ccp_alpha=513107.0498230271, random_state=0), DecisionTreeRegressor(ccp_alpha=525072.4344776655, random_state=0), DecisionTreeRegressor(ccp_alpha=587275.1008268883, random_state=0), DecisionTreeRegressor(ccp_alpha=599025.0007925704, random_state=0), DecisionTreeRegressor(ccp_alpha=633500.7751937985, random_state=0), DecisionTreeRegressor(ccp_alpha=726922.9974160208, random_state=0), DecisionTreeRegressor(ccp_alpha=728689.6831842861, random_state=0), DecisionTreeRegressor(ccp_alpha=733465.5299424306, random_state=0), DecisionTreeRegressor(ccp_alpha=818661.4064295487, random_state=0), DecisionTreeRegressor(ccp_alpha=819919.0444193184, random_state=0), DecisionTreeRegressor(ccp_alpha=839014.4264099114, random_state=0), DecisionTreeRegressor(ccp_alpha=869153.6008517668, random_state=0), DecisionTreeRegressor(ccp_alpha=871139.81049411, random_state=0), DecisionTreeRegressor(ccp_alpha=919068.4983877428, random_state=0), DecisionTreeRegressor(ccp_alpha=947594.6592644751, random_state=0), DecisionTreeRegressor(ccp_alpha=963956.649345845, random_state=0), DecisionTreeRegressor(ccp_alpha=964825.854189653, random_state=0), DecisionTreeRegressor(ccp_alpha=983795.5924257729, random_state=0), DecisionTreeRegressor(ccp_alpha=1030865.3679139651, random_state=0), DecisionTreeRegressor(ccp_alpha=1090130.814001938, random_state=0), DecisionTreeRegressor(ccp_alpha=1115834.7777278088, random_state=0), DecisionTreeRegressor(ccp_alpha=1119791.6666666665, random_state=0), DecisionTreeRegressor(ccp_alpha=1131307.3175321147, random_state=0), DecisionTreeRegressor(ccp_alpha=1166062.0991552658, random_state=0), DecisionTreeRegressor(ccp_alpha=1227030.8251617993, random_state=0), DecisionTreeRegressor(ccp_alpha=1418946.4728814587, random_state=0), DecisionTreeRegressor(ccp_alpha=1439455.1298901737, random_state=0), DecisionTreeRegressor(ccp_alpha=1447111.6925064595, random_state=0), DecisionTreeRegressor(ccp_alpha=1451189.5738586262, random_state=0), DecisionTreeRegressor(ccp_alpha=1472178.8118490428, random_state=0), D ...

# %% [markdown]
# ### 4. Para cada árvore na lista, calcule o MSE da árvore.

# %%
tree_depths = [clf.tree_.max_depth for clf in clfs]
plt.figure(figsize=(10,  6))
plt.plot(ccp_alphas[:-1], tree_depths[:-1])
plt.xlabel("effective alpha")
plt.ylabel("Profundidade da árvore")
# Out:
# Text(0, 0.5, 'Profundidade da árvore')

# %% [markdown]
# ### 5. Monte um gráfico do MSE pelo alpha, escolha um valor de alpha perto do ponto de mínimo do MSE

# %%
train_scores = [mean_squared_error(y_train , clf.predict(X_train)) for clf in clfs]
test_scores  = [mean_squared_error(y_test  , clf.predict(X_test )) for clf in clfs]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("MSE")
ax.set_title("MSE x alpha do conjunto de dados de treino e teste")
ax.plot(ccp_alphas[:-1], train_scores[:-1], marker='o', label="treino",
        drawstyle="steps-post")
ax.plot(ccp_alphas[:-1], test_scores[:-1], marker='o', label="teste",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %% [markdown]
# ### 6. Calcule o R-quadrado dessa árvore encontrada no item acima

# %%
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3 * (0.5 - rng.rand(16))

# %%
 #Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X, y)
regr_2.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
# Predict
X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# %% [markdown]
# ### 7. Visualize esta árvore.

# %%
# Plot the results
plt.figure()
plt.scatter(X, y, s=20, edgecolor="black",
            c="darkorange", label="Dados")
plt.plot(X_test, y_1, color="cornflowerblue",
         label="Profundidade máxima=2", linewidth=2)
plt.plot(X_test, y_2, color="yellowgreen", label="Profundidade máxima=5", linewidth=2)
plt.xlabel("Dados")
plt.ylabel("Resposta")
plt.title("Árvore de regressão")
plt.legend()
plt.show()
